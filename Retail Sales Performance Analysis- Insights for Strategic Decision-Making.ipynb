# %% [markdown]
# ### Objective: To analyze the sales performance of a store, identify trends, and make data-driven decisions.

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Simulate Data
np.random.seed(42)  # For reproducibility
dates = pd.date_range(start="2024-01-01", end="2024-12-31")
categories = ["Electronics", "Clothing", "Groceries", "Furniture"]
data = {
    "Date": np.random.choice(dates, size=1000),
    "Category": np.random.choice(categories, size=1000),
    "Quantity": np.random.randint(1, 10, size=1000),
    "Price": np.random.randint(100, 2000, size=1000),
}
df = pd.DataFrame(data)
df["Revenue"] = df["Quantity"] * df["Price"]

# %%
# Step 3: Basic Analysis
print("First 5 rows of the dataset:")
print(df.head())

print("\nSummary Statistics:")
print(df.describe())

print("\nCategory-wise Summary:")
print(df.groupby("Category")["Revenue"].sum())
# Out:
# First 5 rows of the dataset:
#         Date     Category  Quantity  Price  Revenue
# 0 2024-04-12    Groceries         3    313      939
# 1 2024-12-14    Furniture         4   1778     7112
# 2 2024-09-27  Electronics         7    475     3325
# 3 2024-04-16    Groceries         1    843      843
# 4 2024-03-12    Groceries         6    312     1872
#
# Summary Statistics:
#                       Date     Quantity        Price       Revenue
# count                 1000  1000.000000  1000.000000   1000.000000
# mean   2024-06-30 14:24:00     4.970000  1091.178000   5445.770000
# min    2024-01-01 00:00:00     1.000000   100.000000    100.000000
# 25%    2024-04-07 00:00:00     3.000000   606.250000   1868.500000
# 50%    2024-06-30 12:00:00     5.000000  1103.500000   4316.000000
# 75%    2024-09-26 06:00:00     7.000000  1578.250000   8023.250000
# max    2024-12-31 00:00:00     9.000000  1999.000000  17964.000000
# std                    NaN     2.548646   551.412308   4229.357719
# ...

# %%
# Step 4: Visualizations
# 4.1 Sales Trend Over Time
df["Month"] = pd.to_datetime(df["Date"]).dt.to_period("M")
monthly_revenue = df.groupby("Month")["Revenue"].sum()

plt.figure(figsize=(12, 6))
monthly_revenue.plot(kind="line", marker="o", color="blue")
plt.title("Monthly Revenue Trend", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Revenue", fontsize=12)
plt.grid(True)
plt.show()

# %%
# 4.2 Revenue by Category
category_revenue = df.groupby("Category")["Revenue"].sum()

plt.figure(figsize=(8, 6))
category_revenue.plot(kind="bar", color=["red", "green", "blue", "purple"])
plt.title("Revenue by Category", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Revenue", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Step 5: Insights
print("\nActionable Insights:")
print("- The category with the highest revenue is:", category_revenue.idxmax())
print("- The category with the lowest revenue is:", category_revenue.idxmin())
print("- The store has the highest revenue in the month:", monthly_revenue.idxmax())
print("- The store has the lowest revenue in the month:", monthly_revenue.idxmin())
# Out:
# Actionable Insights:
# - The category with the highest revenue is: Electronics
# - The category with the lowest revenue is: Furniture
# - The store has the highest revenue in the month: 2024-08
# - The store has the lowest revenue in the month: 2024-03
